# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
# import json
# from pprint import pprint

# python_lib=[ {'Data ETL': ['Pandas', 'SQLAlchemy', 'json', 'requests'],
#      'Visualizations': [ 
#          {'Matplotlibs': 'Seaborn'}, 'Plotly', {'Graphviz': ['PyGraphviz', 'Networkx']}, {'GIS': [{'Geopy': {'Geocoders':'Nominatum'}}, 'Folium', ]}],
#      'Calculations': ['Sklearns', 'Scipy', 'Numpy'],
#     'Web Frameworks': ['Django', 'Flask', 'PySpark'],
#      'Web Scraping': ['Beautiful Soup', {'Splinter': 'browser'}]
#                       }]

# # Write the graph data to a JSON file
# with open('python_libraries.json', 'w') as file:
#     json.dump(python_lib, file)

# %%
#python char
# Create an empty graph
G = nx.DiGraph()
# Add nodes to the graph
G.add_node('Python')

G.add_node('Data Tools')

G.add_node('Pandas')
G.add_node('SQLAlchemy')
G.add_node('Json')
G.add_node('Requests')
G.add_node('Datetime')

G.add_node('Calculations')

G.add_node('Sklearns')
G.add_node('Scipy')
G.add_node('Numpy')

G.add_node('Web')
G.add_node('App')
# G.add_node('Scraping')

G.add_node('Django')
G.add_node('HttpResponse')
G.add_node('Flask')
G.add_node('PySpark')

# G.add_node('Scraping')

G.add_node('Selenium')

G.add_node('Beautiful Soup')
G.add_node('Splinter')
G.add_node('Browser')

G.add_node('Visualization')

G.add_node('Matplotlibs')
G.add_node('Seaborn')
G.add_node('Plotly')

G.add_node('Graphviz')
G.add_node('PyGraphviz')
G.add_node('Networkx')

G.add_node('GIS')
G.add_node('Geopy')
G.add_node('Geocoders')
# G.add_node('Nominatum')
G.add_node('Folium')

G.add_node('Text')
G.add_node('Reportlab')
G.add_node('Fitz')
G.add_node('Openai')
G.add_node('Markdown')

# %%
#add edges 
# Add edges between nodes
G.add_edges_from([('Python','Data Tools'), ('Python','Calculations'), ('Python','Text'), ('Python','Visualization'), ('Python','Web'),  ('Web','App'), ('Web','Browser') ])

G.add_edges_from([('Data Tools', 'Pandas'), ('Data Tools', 'PySpark'), ('Data Tools', 'Json'), ('Data Tools', 'Requests'),('Data Tools', 'Datetime')])

G.add_edges_from([('Visualization', 'Matplotlibs'), ('Matplotlibs', 'Seaborn'), ('Visualization', 'Plotly')])

G.add_edges_from([('Visualization', 'Graphviz'), ('Graphviz', 'PyGraphviz'), ('Graphviz', 'Networkx')])

G.add_edges_from([('Visualization', 'GIS'), ('GIS', 'Geopy'), ('Geopy', 'Geocoders'), ('GIS', 'Folium') ])

G.add_edges_from([('Calculations', 'Sklearns'), ('Calculations', 'Scipy'), ('Calculations', 'Numpy')])

G.add_edges_from([('App', 'Django'), ('App', 'Flask'), ('Flask', 'SQLAlchemy'), ('Django', 'HttpResponse'), ('App', 'Openai'),])

G.add_edges_from([('Text', 'Reportlab'), ('Text', 'Markdown'), ('Text', 'Fitz')])

G.add_edges_from([('Browser', 'Splinter'), ('Browser', 'Selenium'), ])

G.add_edges_from([('Selenium', 'Beautiful Soup'), ('Splinter', 'Beautiful Soup'), ('Web', 'Feedparser'), ('Text', 'Feedparser')])

# %%
# Define the layout
# pos = nx.spring_layout(G)
pos = nx.nx_agraph.graphviz_layout(G, prog='dot',)

plt.figure(figsize=(25, 10))
# Customize the plot

# Draw the graph with customized features
nx.draw_networkx(
    G,
    pos=pos,
    with_labels=True,
    node_size=3000,
    node_color='skyblue',
    edge_color='darkgreen',
    width=1.5,
    arrows=True,
    arrowstyle='-',
    font_size=12,
    font_color='black',
    
    alpha=0.5,
    node_shape='p'
)



# # Show the plot
plt.axis('off') 
plt.show()
# plt.savefig('Pythons Libraries 07192023.png', dpi=300)
# plt.savefig('Pythons Libraries 07312023.png', dpi=300)

# %%
#Coding Languages Chart
# javascript_lib = {"Visualization" :['D3', 'Leaflet'], "Web": ['Jquery', 'Popper', 'Bootstraps'] }

# Create an empty graph
J = nx.DiGraph()
# Add nodes to the graph

J.add_node('Javascript')
# J.add_node('R')
J.add_node('HTML')
J.add_node('CSS')
# J.add_node('Java')
# J.add_node('Python')
# J.add_node('C#')


J.add_node('Visualization(JS)')
J.add_node('D3')
J.add_node('Leaflet')
# J.add_node('Charts.js')

J.add_node('Web(JS)')
J.add_node('Jquery')
J.add_node('Popper')
J.add_node('Md-Block')
J.add_node('Bootstraps')
J.add_node('Tailwinds')

J.add_edges_from([('HTML','CSS'), ('CSS','Web(JS)')])
# J.add_edges_from([(' ','R'),(' ','C#')])
# J.add_edges_from([(' ','Java')])
# J.add_edges_from([(' ','Python')])
# J.add_edges_from([(' ','Javascript')])

J.add_edges_from([('Javascript','Visualization(JS)'), ('Javascript','Web(JS)'), ('Visualization(JS)','D3'), ('Visualization(JS)' ,'Leaflet'),
                  ('Web(JS)','Jquery'), ('Web(JS)','Popper'), ('Web(JS)','Bootstraps') , ('Web(JS)','Md-Block'), ('Web(JS)','Tailwinds')])



# Define the layout
# pos = nx.spring_layout(G)
pos_J = nx.nx_agraph.graphviz_layout(J, prog='dot',)

plt.figure(figsize=(8, 8))
# Draw the graph with customized features
nx.draw_networkx(
    J,
    pos=pos_J,
    with_labels=True,
    node_size=1000,
    node_color='lightyellow',
    edge_color='indigo',
    width=2,
    arrows=True,
    arrowstyle='-',
    font_size=10,
    font_color='black',
    alpha=0.7,
    node_shape='o'
)

# %%
#Blank Notess
B = nx.DiGraph()
# Add nodes to the graph
B.add_node(' ')


B.add_node('R')
B.add_node('.Net')
B.add_node('C#')
B.add_node('Java')
B.add_node('XML')
B.add_node('Wordpress')
B.add_node('PHP')


B.add_edges_from([(' ','R'),('.Net','C#'),(' ','.Net'), ('.Net','F#')])

B.add_edges_from([(' ','Java'), (' ','XML'), (' ','PHP'),('PHP','Wordpress')])


B.add_edges_from([('Android','Java'), ('Android','XML'), ('Android','Kotlin'),('Android','F#')])

pos_B = nx.nx_agraph.graphviz_layout(B, prog='dot',)
plt.figure(figsize=(10, 8))

nx.draw_networkx(
    B,
    pos=pos_B,
    with_labels=True,
    node_size=1000,
    node_color='lightyellow',
    edge_color='indigo',
    width=2,
    arrows=True,
    arrowstyle='-',
    font_size=10,
    font_color='black',
    alpha=0.7,
    node_shape='o'
)

C=nx.compose(J,B)

pos_C = nx.nx_agraph.graphviz_layout(C, prog='dot', )

plt.figure(figsize=(15, 8))
# Draw the graph with customized features
nx.draw_networkx(
    C,
    pos=pos_C,
    with_labels=True,
    node_size=1000,
    node_color='lightyellow',
    edge_color='indigo',
    
    width=2,
    arrows=True,
    arrowstyle='-',
    font_size=10,
    font_color='black',
    alpha=0.7,
    node_shape='o'
)

# # Show the plot
plt.axis('off') 
plt.show()
# plt.savefig('JS and Others 07312023.png', dpi=300)

# %%
# Software Chart

# datavis= {'Business Intelligence': ['Microsoft PowerBI'.'Tableau'],
#          'Cloud': ['AWS','Microsoft Azure','Hadoop'],
#          'Data Monitoring': ['Splunk',{'IBM Security Guardium':'ServiceNow','MsSQL', 'Linux', 'Oracle'}],
#           'Database': ['SQL':'Postgres', 'NoSQL':'Mongodb']}

# # Create an empty graph
D = nx.DiGraph()
# Add nodes to the graph
D.add_node('Data Software')


D.add_node('Business Intelligence')
D.add_node('Tableau')
D.add_node('Microsoft PowerBI')

D.add_node('Cloud')
D.add_node('AWS')
D.add_node('Microsoft Azure')
D.add_node('Hadoop')

D.add_node('Project Management')
D.add_node('Jira')
D.add_node('Github')


D.add_node('Security and Monitoring')
D.add_node('SCADA')
D.add_node('ERP')
D.add_node('WMS')
D.add_node('Splunk')
D.add_node('IBM Security Guardium')
D.add_node('Server')
D.add_node('Oracle')
D.add_node('MsSQL')
D.add_node('Linux')

D.add_node('Databases')
D.add_node('SQL')
D.add_node('Postgres')
D.add_node('NoSQL')
D.add_node('Mongodb')

D.add_edges_from([('Data Software','Business Intelligence'), ('Data Software','Project Management'),('Data Software','Cloud'),('Data Software','Security and Monitoring'),('Data Software','Databases')])


D.add_edges_from([('Business Intelligence','Tableau'),('Business Intelligence','Microsoft PowerBI')])
D.add_edges_from([('Cloud','AWS'),('Cloud','Microsoft Azure'),('Cloud','Hadoop')])
D.add_edges_from([('Project Management','Github'),('Project Management','Jira'),('Project Management','SAP')])
D.add_edges_from([('Security and Monitoring','Splunk'),('Security and Monitoring','IBM Security Guardium'),('IBM Security Guardium', 'Server'), ('Server','MsSQL'),('Server','Oracle'),('Server','Linux')])
D.add_edges_from([('Security and Monitoring','SCADA'), ('SCADA','WMS'),('SCADA','ERP') ])

D.add_edges_from([('Databases','SQL'),('SQL','Postgres'),('Databases', 'NoSQL'), ('NoSQL','Mongodb')])


pos_D = nx.nx_agraph.graphviz_layout(D, prog='dot', )

plt.figure(figsize=(25, 10))
# Draw the graph with customized features
nx.draw_networkx(D,
    pos=pos_D,
    with_labels=True,
    node_size=2000,
    node_color='blanchedalmond',
    edge_color='lightblue',
    width=2,
    arrows=True,
    arrowstyle='<-',
    font_size=12,
    font_color='black',
    alpha=0.7,
    node_shape='s'
)

plt.axis('off') 
plt.show()
# plt.savefig('DataManagement 07312023.png', dpi=300)

# %%
# full Coding Chart

F = nx.compose(C,G)

C.nodes(data=True)
G.nodes(data=True)
F.nodes(data=True)

C.edges(data=True)
G.edges(data=True)
F.edges(data=True)
plt.figure(figsize=(25, 20))

# pos_F = nx.spectral_layout(F)

pos_F = nx.nx_agraph.graphviz_layout(F, prog='neato')
# pos_F = nx.nx_agraph.graphviz_layout(F, prog='sfdp')

# Draw the graph with customized features
nx.draw_networkx(F,
    pos=pos_F,
    with_labels=True,
    node_size=5000,
    node_color='antiquewhite',
    font_family='Candara',  
    edge_color='firebrick',
    width=1.2,
    arrows=True,
    arrowstyle='-',
    font_size=12,
    font_color='black',
    alpha=0.7,
    node_shape='4'
)


# plt.title('Coding Languages and Their Libraries')

plt.axis('off') 
# plt.show()
plt.savefig('Skill-List-Code 7-19-23.png', dpi=300)
# plt.savefig('Skill-List-Code 7-31-23.png', dpi=300)

# %%
# Automation Charts

# Industy

M = nx.DiGraph()

m=' '

M.add_node(m)

M.add_node('Robots')
M.add_node('Kuka')
M.add_node('ABB')
M.add_node('Staubli')
M.add_node('TGW Stingray')

M.add_node('PLC')
M.add_node('Allen Bradley')
M.add_node('Siemens')
M.add_node('Siemens S5')
M.add_node('Function Block Diagram')
M.add_node('Ladder Diagram')
M.add_node('DirectLOGIC')

M.add_node('Automated Warehouse')
M.add_node('Honeywell Intelligrated')
M.add_node('BOSS System')
M.add_node('AS/RS')
M.add_node('TGW')

M.add_node('Systems&Schematics')
M.add_node('Relay Ladder Logic')
M.add_node('Mechanical')
M.add_node('Electrical')
M.add_node('Panels')
M.add_node('Pneumatic')
M.add_node('Hydraulic')

M.add_node('Software')
M.add_node('SAP')
M.add_node('NI MultiSim')

M.add_edges_from([(m,'Robots'),(m,'PLC'),(m,'Automated Warehouse'),(m,'Systems&Schematics'), (m,'Software')])

M.add_edges_from([('Robots','Kuka'),('Robots','ABB'),('Robots','Staubli'),('Robots','TGW Stingray')])

M.add_edges_from([('PLC','Allen Bradley'),('PLC','DirectLOGIC'),('PLC','Siemens')])
M.add_edges_from([('Siemens S5','Ladder Diagram'),('Siemens S5','Function Block Diagram')])

M.add_edges_from([('Automated Warehouse','Honeywell Intelligrated'),('Automated Warehouse','AS/RS'),('AS/RS','TGW')])
M.add_edges_from([('Honeywell Intelligrated','BOSS System'),('TGW','TGW Stingray')])

M.add_edges_from([('Systems&Schematics','Mechanical'),('Mechanical','Pneumatic'),('Mechanical','Hydraulic')])
M.add_edges_from([('Systems&Schematics','Electrical'),('Electrical','Relay Ladder Logic'),('Electrical','Electronic Circuit'), ('Electrical','Panels')])

M.add_edges_from([('Software','SAP'),('BOSS System','Software'),('Software','NI MultiSim')])

M.add_edges_from([('Siemens S5','Software'), ('Electronic Circuit','Software')])

pos_M = nx.nx_agraph.graphviz_layout(M, prog='neato')

# pos_M = nx.spring_layout(M, k=0.30, iterations=20)
plt.figure(figsize=(15, 12))
# Draw the graph with customized features
nx.draw_networkx(M,
    pos=pos_M,
    with_labels=True,
    node_size=950,
    node_color='seagreen',
    edge_color='orange',
    width=1.5,
    arrows=True,
    arrowstyle='-|>',
    font_size=8,
    font_color='black',
    alpha=0.4,
    node_shape='h'
)
plt.axis('off') 
plt.show()
# plt.savefig('Mechatronics and Automation 7-18-23.png', dpi=300)

# %%
# WorkProcess

W = nx.DiGraph()

# W.add_node(' ')

W.add_node('Agile')
W.add_node('SCRUM')
W.add_node('Kanban')

# W.add_node('S5')
# W.add_node('Sort')
# W.add_node('Set in Order')
# W.add_node('Shine')
# W.add_node('Standardize')
# W.add_node('Sustain')

W.add_edges_from([('Agile','Manifesto'),('Agile','SCRUM'),('Agile','Kanban')])
W.add_edges_from([('Kanban','Backlog'),('Kanban','Plan'),('Kanban','Doing'),('Kanban','Review'),('Kanban','Done')])

W.add_edges_from([('Agile','Initiatives'),('Initiatives','Epics'),('Epics','Stories')])

W.add_edges_from([('SCRUM','Participants'),('SCRUM','Ceremonies'),('SCRUM','Artifacts')])
W.add_edges_from([('Participants','Product Owner/Manager'),('Participants','SCRUM Master/Lead'),('Participants','Members')])
W.add_edges_from([('Ceremonies','Two-Week Sprint'),('Ceremonies','Review and Retrospective'),('Ceremonies','Daily Scrum')])
W.add_edges_from([('Artifacts','Product Backlog'),('Artifacts','Sprint Backlog'),('Artifacts','Product Increment'),('Artifacts','Burndown Chart')])


W.add_edges_from([('Manifesto','Individuals/Interactions over Processes/Tools'),('Manifesto','Working Software over Documentation')
                    ,('Manifesto','Customer Collaboration over Negotiation'),('Manifesto','Responding to Change over Plan')])


W.add_edges_from([('DevOps','1. Discover'),('DevOps','2. Plan'),('DevOps','3. Build'),('DevOps','4. Test'),('DevOps','5. Deploy'), ('DevOps','6. Operate'),('DevOps','7. Observe'),('DevOps','8. Continuous feedback')])


# pos_W = nx.nx_agraph.graphviz_layout(W, prog='dot', args="-Grankdir=LR")
# pos_W = nx.spectral_layout(W)
pos_W = nx.nx_agraph.graphviz_layout(W, prog='circo')

# pos_M = nx.spring_layout(M, k=0.30, iterations=20)
plt.figure(figsize=(20, 15))
# Draw the graph with customized features
nx.draw_networkx(W,
    pos=pos_W,  with_labels=True,
    node_size=3500,
    node_color='white',
    edge_color='grey',
    width=1,
    arrows=True,
    arrowstyle='->',
    font_size=8,
    font_color='red',
    alpha=0.8,
    node_shape='o')

plt.axis('off') 
# plt.savefig('Agile-DevOp 7-31-23.png', dpi=300)

# %%
W.add_edges_from([('S5','1. Sort'),('S5','2. Set in Order'),('S5','3. Shine'),('S5','4. Standardize'),('S5','5. Sustain')])


W.add_edges_from([('DevOps','1. Discover'),('DevOps','2. Plan'),('DevOps','3. Build'),('DevOps','4. Test'),('DevOps','5. Deploy'), ('DevOps','6. Operate'),('DevOps','7. Observe'),('DevOps','8. Continuous feedback')])

# %%
# #finding font list
# import matplotlib.font_manager as fm

# # Get the list of available fonts
# font_list = fm.findSystemFonts()

# # Print the list of fonts
# for font_path in font_list:
#     font_name = fm.get_font(font_path).family_name
#     print(font_name)

# %%
# save it to pdf
from reportlab.pdfgen import canvas

# Create a new PDF file
pdf = canvas.Canvas("example.pdf")

# Set the font and font size
pdf.setFont("Helvetica", 12)

# Add some text to the PDF
text = "Hello, World!"
pdf.drawString(100, 100, text)

# Save the PDF file
pdf.save()

# %%
#Django and Openai

D = nx.DiGraph()

D.add_node('Django')

D.add_node('API')
D.add_node('OpenAi')
D.add_node('DALL-E')

D.add_node('Text to Speech')
D.add_node('gTTS')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #Django and Openai
# ----> 3 D = nx.DiGraph()
#       5 D.add_node('Django')
#       7 D.add_node('API')
#
# NameError: name 'nx' is not defined
